# %% [raw]
# ---
# layout: post
# title: Tools Verify using Shell
# description: Linux and the shell is used in this example to setup and verify the installation of the tools.  Additionally, a few programming exercises are included.
# categories: [DevOps]
# permalink: /devops/tools/verify
# menu: nav/tools_setup.html
# toc: true
# comments: true
# ---

# %% [markdown]
# ## Computers and Terminals
#
# A brief overview of Terminal and Linux is a step on your way to becoming a Linux expert. When a computer boots up, **a kernel (MacOS, Windows, Linux) is started**. This kernel is the core of the operating system and manages hardware resources. Above the kernel, various applications run, including the **shell** and **terminal**, which allow users to interact with the system using a basic set of commands provided by the kernel.
#
# Typically, casual users interact with the system through a Desktop User Interface (UI) that is started by the computer's boot-up processes. However, to interact directly with the shell, users can run a "terminal" application through the Desktop UI. Additionally, **VS Code provides the ability to activate a "terminal"** within its editing environment, making it convenient for developers to execute commands without leaving the code editor.
#
# In this next phase, we will use a Jupyter notebook to perform Linux commands through a terminal. The Jupyter notebook is an application that runs above the kernel, providing an interactive environment for writing and executing code, including shell commands. This setup allows us to seamlessly integrate code execution, data analysis, and documentation in one place, enhancing our productivity and learning experience.

# %% [markdown]
# ## Setup a Personal GitHub Pages Project
#
# You will be making a personal copy of the course repository. Be sure to have a GitHub account!!!
#
# - Use the **Green "Use this Template"** button on the [portfolio_2025](https://github.com/nighthawkcoders/portfolio_2025) repository page to set up your personal GitHub Pages repository.
# - Create a new repository.
# - Fill in the dialog and select the **Repository Name** to be under your GitHub ID ownership.
#
#     ![create repo]({{ site.baseurl }}/images/notebooks/foundation/create_repo.jpg)
#
# - After this is complete, use the **Green "Code"** button on the newly created repository page to capture your "Project Repo" name.
#
# In the next few code cells, we will run a bash (shell) script to pull a GitHub project.

# %% [markdown]
# ## Shell Script and Variables
#
# We will ultimately run a bash (shell) script to pull a GitHub project. This next script simply sets up the necessary **environment variables** to tell the script the location of repository from GitHub and where to copy the output.
#
# For now, focus on each line that begins with `export`. These are **shell variables**. Each line has a **name** (after the keyword `export`) and a **value** (after the equal sign).
#
# Here is a full description:
#
# - **Creates a temporary file** `/tmp/variables.sh` to store environment variables.
# - **Sets the `project_dir` variable** to your home directory with a subdirectory named `nighthawk`. You can change `nighthawk` to a different name to test your git clone.
# - **Sets the `project` variable** to a subdirectory within `project_dir` named `portfolio_2025`. You can change `portfolio_2025` to the name of your project.
# - **Sets the `project_repo` variable** to the URL of the GitHub repository. Change this to the project you created from the `portfolio_2025` template.
#
# **By running this script, you will prepare your environment for cloning** and working on your GitHub project. This is an essential step in setting up your development environment and ensuring that all dependencies are correctly configured.

# %%
# %%script bash
#
# # Dependency Variables, set to match your project directories
#
# cat <<EOF > /tmp/variables.sh
# export project_dir=$HOME/nighthawks  # change nighthawk to different name to test your git clone
# export project=\$project_dir/Elise_Portfolio_2025  # change portfolio_2025 to name of project from git clone
# export project_repo="https://github.com/blueelephant48/Elise_Portfolio_2025.git"  # change to project you created from portfolio_2025 template
# EOF

# %% [markdown]
# ## Describing the Outputs of the Variables
#
# The next script will extract the saved variables and display their values. Here is a description of the commands:
#
# - The `source` command loads the variables that we saved in the `/tmp/variables.sh` file in the previous code cell.
# - The `echo` commands display the contents of the named variables:
#   - **project_dir**: The directory where your project is located.
#   - **project**: The specific project directory within `project_dir`.
#   - **project_repo**: The URL of the GitHub repository.
#
# By running this script, you can verify that the environment variables are correctly set in your development environment. If they don't match up, go back to the previous code cell and make the necessary corrections.

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# # Output shown title and value variables
# echo "Project dir: $project_dir"
# echo "Project: $project"
# echo "Repo: $project_repo"
# Out:
# Project dir: /home/blueelephant48/nighthawks
# Project: /home/blueelephant48/nighthawks/Elise_Portfolio_2025
# Repo: https://github.com/blueelephant48/Elise_Portfolio_2025.git

# %% [markdown]
# ## Project Setup and Analysis with Bash Scripts
# The bash scripts that follow automate what was done in the Tools Installation procedures with regards to cloning a GitHub project. Doing this in a script fashion adds the following benefits:
#
# - After completing these steps, we will have notes on how to set up and verify a project.
# - By reviewing these commands, you will start to learn the basics of Linux.
# - By setting up these code cells, you will be learning how to develop automated scripts using Shell programming.
# - You will learn that pretty much anything we type on a computer can be automated through the use of variables and a coding language.

# %% [markdown]
# ### Pull Code
#
# > Pull code from GitHub to your machine. This is a **bash script**, a sequence of commands, that will create a project directory and add the "project" from GitHub to the vscode directory. There is conditional logic to make sure that the clone only happens if it does not (!) exist. Here are some key elements in this code:
#
# - `cd` command (change directory), remember this from the terminal session.
# - `if` statements (conditional statements, called selection statements by College Board), code inside only happens if the condition is met.
#
# Run the script two times and you will see that the output changes.  In the second run, the files exist and it impact the flow of the code.

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Using conditional statement to create a project directory and project"
#
# cd ~    # start in home directory
#
# # Conditional block to make a project directory
# if [ ! -d $project_dir ]
# then
#     echo "Directory $project_dir does not exist... making directory $project_dir"
#     mkdir -p $project_dir
# fi
# echo "Directory $project_dir exists."
#
# # Conditional block to git clone a project from project_repo
# if [ ! -d $project ]
# then
#     echo "Directory $project does not exist... cloning $project_repo"
#     cd $project_dir
#     git clone $project_repo
#     cd ~
# fi
# echo "Directory $project exists."
# Out:
# Using conditional statement to create a project directory and project
# Directory /home/blueelephant48/nighthawks exists.
# Directory /home/blueelephant48/nighthawks/Elise_Portfolio_2025 exists.

# %% [markdown]
# ### Look at Files in GitHub Project
#
# > All computers contain files and directories. The clone brought more files from the cloud to your machine. Review the bash shell script, observe the commands that show and interact with files and directories. These were used during setup.
#
# - `ls` lists computer files in Unix and Unix-like operating systems.
# - `cd` offers a way to navigate and change the working directory.
# - `pwd` prints the working directory.
# - `echo` is used to display a line of text/string that is passed as an argument.

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Navigate to project, then navigate to area wwhere files were cloned"
# cd $project
# pwd
#
# echo ""
# echo "list top level or root of files with project pulled from github"
# ls
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# /home/blueelephant48/nighthawks/Elise_Portfolio_2025
#
# list top level or root of files with project pulled from github
# 404.html
# Gemfile
# Gemfile.lock
# LICENSE
# Makefile
# README.md
# README4YML.md
# _config.yml
# _data
# _includes
# _layouts
# _notebooks
# _posts
# _sass
# assets
# design
# images
# index.md
# kasm_design
# navigation
# node_backend
# requirements.txt
# scripts

# %% [markdown]
# ### Look at File List with Hidden and Long Attributes
#
# > Most Linux commands have options to enhance behavior. The enhanced listing below shows permission bits, owner of the file, size, and date.
#
# Some useful `ls` flags:
# - `-a`: List all files including hidden files.
# - `-l`: List in long format.
# - `-h`: Human-readable file sizes.
# - `-t`: Sort by modification time.
# - `-R`: Reverse the order of the sort.
#
# [ls reference](https://www.rapidtables.com/code/linux/ls.html)

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Navigate to project, then navigate to area wwhere files were cloned"
# cd $project
# pwd
#
# echo ""
# echo "list all files in long format"
# ls -al   # all files -a (hidden) in -l long listing
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# /home/blueelephant48/nighthawks/Elise_Portfolio_2025
#
# list all files in long format
# total 152
# drwxr-xr-x 17 blueelephant48 blueelephant48  4096 Dec 10 11:52 .
# drwxr-xr-x  3 blueelephant48 blueelephant48  4096 Dec  5 12:18 ..
# drwxr-xr-x  8 blueelephant48 blueelephant48  4096 Dec 12 11:54 .git
# drwxr-xr-x  3 blueelephant48 blueelephant48  4096 Dec  5 12:18 .github
# -rw-r--r--  1 blueelephant48 blueelephant48   455 Dec  5 12:18 .gitignore
# -rw-r--r--  1 blueelephant48 blueelephant48   436 Dec  5 12:18 404.html
# -rw-r--r--  1 blueelephant48 blueelephant48   122 Dec  5 12:18 Gemfile
# -rw-r--r--  1 blueelephant48 blueelephant48  8525 Dec  6 11:55 Gemfile.lock
# -rw-r--r--  1 blueelephant48 blueelephant48 11357 Dec  5 12:18 LICENSE
# -rw-r--r--  1 blueelephant48 blueelephant48  5524 Dec  6 11:44 Makefile
# -rw-r--r--  1 blueelephant48 blueelephant48 14185 Dec  5 12:18 README.md
# -rw-r--r--  1 blueelephant48 blueelephant48    99 Dec  5 12:18 README4YML.md
# -rw-r--r--  1 blueelephant48 blueelephant48   874 Dec 12 11:20 _config.yml
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 _data
# drwxr-xr-x  4 blueelephant48 blueelephant48  4096 Dec  5 12:18 _includes
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 _layouts
# drwxr-xr-x  7 blueelephant48 blueelephant48  4096 Dec  5 12:18 _notebooks
# drwxr-xr-x  8 blueelephant48 blueelephant48  4096 Dec  6 11:58 _posts
# drwxr-xr-x  5 blueelephant48 blueelephant48  4096 Dec  5 12:18 _sass
# drwxr-xr-x  6 blueelephant48 blueelephant48  4096 Dec  5 12:18 assets
# drwxr-xr-x  3 blueelephant48 blueelephant48  4096 Dec  5 12:18 design
# drwxr-xr-x 16 blueelephant48 blueelephant48  4096 Dec  5 12:18 images
# -rw-r--r--  1 blueelephant48 blueelephant48 12193 Dec  5 12:18 index.md
# drwxr-xr-x  4 blueelephant48 blueelephant48  4096 Dec  5 12:18 kasm_design
# drwxr-xr-x  4 blueelephant48 blueelephant48  4096 Dec  5 12:18 navigation
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 node_backend
# -rw-r--r--  1 blueelephant48 blueelephant48    57 Dec  5 12:18 requirements.txt
# drwxr-xr-x  3 blueelephant48 blueelephant48  4096 Dec  6 11:55 scripts

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Look for posts"
# export posts=$project/_posts  # _posts inside project
# cd $posts  # this should exist per fastpages
# pwd  # present working directory
# ls -lR  # list posts recursively
# Out:
# Look for posts
# /home/blueelephant48/nighthawks/Elise_Portfolio_2025/_posts
# .:
# total 152
# -rw-r--r-- 1 blueelephant48 blueelephant48  4326 Dec  5 12:18 2023-08-21-python_flask.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  7134 Dec  6 11:58 2023-08-23-jupyter-notebook-python_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 11348 Dec  5 12:18 2023-08-30-agile_methodolgy.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  6265 Dec  5 12:18 2023-08-31-javascript_project-binary-calculator.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  6712 Dec  5 12:18 2023-08-31-javascript_project-calculator.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  5707 Dec  5 12:18 2023-08-31-javascript_project-game-of-life.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3811 Dec  5 12:18 2023-08-31-javascript_project-music-api.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 14282 Dec  5 12:18 2023-08-31-javascript_project-snake-game.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3683 Dec  5 12:18 2023-09-12-python-flask-repo.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 48002 Dec  5 12:18 2023-10-03-java-types-student-2.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48   257 Dec  5 12:18 2024-09-19-bathroom_pass.md
# drwxr-xr-x 7 blueelephant48 blueelephant48  4096 Dec  6 11:57 CSA
# drwxr-xr-x 4 blueelephant48 blueelephant48  4096 Dec  6 12:02 CSP
# drwxr-xr-x 5 blueelephant48 blueelephant48  4096 Dec  6 12:02 CSSE
# drwxr-xr-x 8 blueelephant48 blueelephant48  4096 Dec  6 11:58 Foundation
# drwxr-xr-x 7 blueelephant48 blueelephant48  4096 Dec  6 11:57 KASM
# drwxr-xr-x 4 blueelephant48 blueelephant48  4096 Dec  5 12:18 Kasm
#
# ./CSA:
# total 44
# -rw-r--r--  1 blueelephant48 blueelephant48  6107 Dec  6 11:57 2024-10-06-sprint2_plan_IPYNB_2_.md
# -rw-r--r--  1 blueelephant48 blueelephant48 11039 Dec  6 11:55 2024-10-29-sprint3_plan_IPYNB_2_.md
# -rw-r--r--  1 blueelephant48 blueelephant48  2877 Dec  6 11:55 2024-11-12-sprint4_plan_IPYNB_2_.md
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  6 11:57 chatgpt
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  6 11:55 fullstack_java
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  6 11:57 spring_boot
# drwxr-xr-x 12 blueelephant48 blueelephant48  4096 Dec  6 11:56 units_1_to_10
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  6 11:57 units_1_to_10_quiz
#
# ./CSA/chatgpt:
# total 20
# -rw-r--r-- 1 blueelephant48 blueelephant48 2698 Dec  5 12:18 2024-07-11-GPTchatbot.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 4619 Dec  6 11:57 2024-07-16-chatgpt-code_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 6810 Dec  6 11:57 2024-07-16-chatgpt-intro_IPYNB_2_.md
#
# ./CSA/fullstack_java:
# total 40
# -rw-r--r-- 1 blueelephant48 blueelephant48  3542 Dec  6 11:55 2024-07-21-Fullstack-intro_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  9345 Dec  6 11:55 2024-07-22-Fullstack-backend_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  
IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3202 Dec  6 12:02 2023-09-22-game_animations-background_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  7923 Dec  6 12:02 2023-09-22-game_animations-player_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  7924 Dec  6 12:02 2023-09-26-game_animations-hacks_IPYNB_2_.md
#
# ./CSSE/javascript:
# total 4
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 12:02 fundamentals
#
# ./CSSE/javascript/fundamentals:
# total 60
# -rw-r--r-- 1 blueelephant48 blueelephant48 16497 Dec  6 12:02 2024-09-30-data-types-operations_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 29458 Dec  6 12:02 2024-09-30-for_sprites_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  8136 Dec  6 12:02 2024-09-30-variables_IO_IPYNB_2_.md
#
# ./CSSE/mario:
# total 8
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 12:02 background
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 12:02 enemy
#
# ./CSSE/mario/background:
# total 0
#
# ./CSSE/mario/enemy:
# total 20
# -rw-r--r-- 1 blueelephant48 blueelephant48 19297 Dec  6 12:02 2023-08-05-mario_goomba_IPYNB_2_.md
#
# ./Foundation:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 3139 Dec  6 11:57 2024-08-21-sprint1_plan_IPYNB_2_.md
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 A-pair_programming
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 B-tools_and_equipment
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 C-github_pages
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:58 D-sass_basics
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:58 E-frontend_development
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 F-projects
#
# ./Foundation/A-pair_programming:
# total 16
# -rw-r--r-- 1 blueelephant48 blueelephant48  3242 Dec  6 11:57 2023-08-16-pair_showcase_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 10043 Dec  6 11:57 2023-08-17-pair_habits_IPYNB_2_.md
#
# ./Foundation/B-tools_and_equipment:
# total 92
# -rw-r--r-- 1 blueelephant48 blueelephant48  8196 Dec  6 11:57 2023-08-19-devops_accounts_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  4949 Dec  6 11:57 2023-08-21-devops_tools-home_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 18181 Dec  6 11:57 2023-08-21-devops_tools-setup_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 16136 Dec  6 11:57 2023-08-22-devops_tools-verify_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 25963 Dec  6 11:57 2023-08-23-devops-githhub_pages-play_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  7507 Dec  6 11:57 2023-08-23-devops-hacks_IPYNB_2_.md
#
# ./Foundation/C-github_pages:
# total 48
# -rw-r--r-- 1 blueelephant48 blueelephant48  8304 Dec  6 11:57 2023-08-23-github_pages-intro_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 10533 Dec  6 11:57 2023-08-23-github_pages-markdonwn_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  8006 Dec  6 11:57 2023-08-24-github_pages-anatomy_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  2407 Dec  6 11:57 2023-08-25-github_pages-utterances_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  7298 Dec  6 11:57 2023-08-26-github-pages-jekyll_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  1371 Dec  6 11:57 2023-08-27-github-pages-hacks_IPYNB_2_.md
#
# ./Foundation/D-sass_basics:
# total 44
# -rw-r--r-- 1 blueelephant48 blueelephant48 8355 Dec  6 11:58 2023-09-01-SASS-basics-play_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 8380 Dec  6 11:58 2023-09-01-SASS_basics-intro_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 9655 Dec  6 11:58 2023-09-02-SASS_basics-coding_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 5407 Dec  6 11:58 2024-07-20-SASS-hacks_IPYNB_2_.md
#
# ./Foundation/E-frontend_development:
# total 76
# -rw-r--r-- 1 blueelephant48 blueelephant48  3583 Dec  6 11:58 2023-08-27-frontend-basics-playground_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3566 Dec  6 11:57 2023-08-28-frontend-basics-html_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3515 Dec  6 11:58 2023-08-28-frontend-basics-js-errors_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  9570 Dec  6 11:58 2023-08-29-frontend-basics-of-js_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 11902 Dec  6 11:57 2023-08-30-frontend-basics-js-data-types_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  7883 Dec  6 11:58 2023-08-30-frontend-basics-js-with-html_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  8868 Dec  6 11:58 2023-08-30-frontend-input_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 18587 Dec  6 11:58 2023-08-30-frontend-output_objects_IPYNB_2_.md
#
# ./Foundation/F-projects:
# total 8
# -rw-r--r-- 1 blueelephant48 blueelephant48 5548 Dec  6 11:57 2023-08-30-javascript_project-play_IPYNB_2_.md
#
# ./KASM:
# total 20
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 Config_Guides
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 Database
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 MultiServer
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 User_Guide
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  6 11:57 Workspaces
#
# ./KASM/Config_Guides:
# total 24
# -rw-r--r-- 1 blueelephant48 blueelephant48 2283 Dec  6 11:57 2024-07-05-docker-cronjob-for-containers_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 2177 Dec  6 11:57 2024-07-05-manual-addition-of-docker-images_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  657 Dec  6 11:57 2024-07-12-security-group-configuration_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 2036 Dec  6 11:57 2024-07-15-manual-registry-addition_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  989 Dec  6 11:57 2024-07-15-persistent-data_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 1411 Dec  6 11:57 2024-07-31-plans-for-big-meet_IPYNB_2_.md
#
# ./KASM/Database:
# total 36
# -rw-r--r-- 1 blueelephant48 blueelephant48  9174 Dec  6 11:57 2024-08-10-rds-documentation_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3509 Dec  6 11:57 2024-08-14-migration_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 19322 Dec  6 11:57 2024-08-14-python-api-4-kasm_IPYNB_2_.md
#
# ./KASM/MultiServer:
# total 24
# -rw-r--r-- 1 blueelephant48 blueelephant48 14296 Dec  6 11:57 2024-07-30-autoscale-config_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  1795 Dec  6 11:57 2024-08-07-persistent-storage_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  2619 Dec  6 11:57 2024-08-14-workspace-registry-admin_IPYNB_2_.md
#
# ./KASM/User_Guide:
# total 12
# -rw-r--r-- 1 blueelephant48 blueelephant48 8952 Dec  6 11:57 2024-11-17-user-kasm_IPYNB_2_.md
#
# ./KASM/Workspaces:
# total 16
# -rw-r--r-- 1 blueelephant48 blueelephant48 7064 Dec  6 11:57 2024-08-14-container-building_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  722 Dec  6 11:57 2024-08-14-dockerhub-push_IPYNB_2_.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 2063 Dec  6 11:57 2024-08-14-nighthawk-registry_IPYNB_2_.md
#
# ./Kasm:
# total 8
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Config_Guides
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 MultiServer
#
# ./Kasm/Config_Guides:
# total 4
# -rw-r--r-- 1 blueelephant48 blueelephant48 3167 Dec  5 12:18 2024-07-12-terraform-vs-ansible.md
#
# ./Kasm/MultiServer:
# total 80
# -rw-r--r-- 1 blueelephant48 blueelephant48 55630 Dec  5 12:18 2024-07-12-multiserver-development.md
# -rw-r--r-- 1 blueelephant48 blueelephant48 21730 Dec  5 12:18 2024-07-12-multiserver-install.md

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Look for notebooks"
# export notebooks=$project/_notebooks  # _notebooks is inside project
# cd $notebooks   # this should exist per fastpages
# pwd  # present working directory
# ls -lR  # list notebooks recursively
# Out:
# Look for notebooks
# /home/blueelephant48/nighthawks/Elise_Portfolio_2025/_notebooks
# .:
# total 32
# -rw-r--r-- 1 blueelephant48 blueelephant48 10436 Dec  5 12:18 2023-08-23-jupyter-notebook-python.ipynb
# drwxr-xr-x 7 blueelephant48 blueelephant48  4096 Dec  5 12:18 CSA
# drwxr-xr-x 4 blueelephant48 blueelephant48  4096 Dec  5 12:18 CSP
# drwxr-xr-x 6 blueelephant48 blueelephant48  4096 Dec  5 12:18 CSSE
# drwxr-xr-x 8 blueelephant48 blueelephant48  4096 Dec  5 12:18 Foundation
# drwxr-xr-x 7 blueelephant48 blueelephant48  4096 Dec  5 12:18 KASM
#
# ./CSA:
# total 48
# -rw-r--r--  1 blueelephant48 blueelephant48  7656 Dec  5 12:18 2024-10-06-sprint2_plan.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48 13861 Dec  5 12:18 2024-10-29-sprint3_plan.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48  3576 Dec  5 12:18 2024-11-12-sprint4_plan.ipynb
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 chatgpt
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 fullstack_java
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 spring_boot
# drwxr-xr-x 12 blueelephant48 blueelephant48  4096 Dec  5 12:18 units_1_to_10
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 units_1_to_10_quiz
#
# ./CSA/chatgpt:
# total 20
# -rw-r--r-- 1 blueelephant48 blueelephant48 6512 Dec  5 12:18 2024-07-16-chatgpt-code.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 8992 Dec  5 12:18 2024-07-16-chatgpt-intro.ipynb
#
# ./CSA/fullstack_java:
# total 52
# -rw-r--r-- 1 blueelephant48 blueelephant48  4384 Dec  5 12:18 2024-07-21-Fullstack-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 12072 Dec  5 12:18 2024-07-22-Fullstack-backend.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  2909 Dec  5 12:18 2024-07-22-Fullstack-design.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  8793 Dec  5 12:18 2024-07-22-Fullstack-example.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 16364 Dec  5 12:18 2024-07-22-Fullstack-frontend.ipynb
#
# ./CSA/spring_boot:
# total 88
# -rw-r--r-- 1 blueelephant48 blueelephant48 13861 Dec  5 12:18 2023-10-14-java-spring-anatomy.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  3465 Dec  5 12:18 2023-10-15-java-spring-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7862 Dec  5 12:18 2023-10-16-java-spring-ui.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  9170 Dec  5 12:18 2023-10-17-java-spring-api.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 25586 Dec  5 12:18 2023-10-17-java-spring-pojo.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  9449 Dec  5 12:18 2023-10-18-java-spring-jpa.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  5203 Dec  5 12:18 2023-10-22-java-spring-hacks.ipynb
#
# ./CSA/units_1_to_10:
# total 40
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec  5 12:18 backup_summer_2024
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_01
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_02
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_03
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_04
# drwxr-xr-x 4 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_05
# drwxr-xr-x 4 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_06
# drwxr-xr-x 4 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_07
# drwxr-xr-x 4 blueelephant48 blueelephant48 4096 Dec  5 12:18 unit_08
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec
ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 22289 Dec  5 12:18 2024-01-27-flask-deploy-aws.ipynb
#
# ./CSSE:
# total 124
# -rw-r--r--  1 blueelephant48 blueelephant48 24224 Dec  5 12:18 2023-12-07-CSSE-platform_student.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48 11146 Dec  5 12:18 2023-12-10-CSSE-parallax_student.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48 10855 Dec  5 12:18 2023-12-11-CSSE-student_animation.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48 20900 Dec  5 12:18 2023-12-13-CSSE-student_Selection_LocalStorage.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48 12565 Dec  5 12:18 2023-12-14-CSSE_student_leaderboard.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48  3847 Dec  5 12:18 2024-10-09-sprint2_plan.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48  8867 Dec  5 12:18 2024-11-04-sprint3_plan.ipynb
# -rw-r--r--  1 blueelephant48 blueelephant48  3404 Dec  5 12:18 2024-11-18-sprint4_plan.ipynb
# drwxr-xr-x  2 blueelephant48 blueelephant48  4096 Dec  5 12:18 A-Game-Intro-RPG
# drwxr-xr-x 12 blueelephant48 blueelephant48  4096 Dec  5 12:18 Lessons
# drwxr-xr-x  3 blueelephant48 blueelephant48  4096 Dec  5 12:18 javascript
# drwxr-xr-x  8 blueelephant48 blueelephant48  4096 Dec  5 12:18 mario
#
# ./CSSE/A-Game-Intro-RPG:
# total 64
# -rw-r--r-- 1 blueelephant48 blueelephant48  4549 Dec  5 12:18 2023-09-20-game_animations-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 14802 Dec  5 12:18 2023-09-21-game_animations-anatomy.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  5898 Dec  5 12:18 2023-09-21-game_animations-json-object.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  5268 Dec  5 12:18 2023-09-22-game_animations-background.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 10791 Dec  5 12:18 2023-09-22-game_animations-player.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  9952 Dec  5 12:18 2023-09-26-game_animations-hacks.ipynb
#
# ./CSSE/Lessons:
# total 48
# -rw-r--r-- 1 blueelephant48 blueelephant48 4509 Dec  5 12:18 2024-11-09-sprint3_lessons.ipynb
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Arrays
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Booleans
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Classes_and_Methods
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Conditions
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Data_Abstractions
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Iteration
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Mathematic_Expressions
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Nested_Conditionals
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Strings
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Variables
#
# ./CSSE/Lessons/Arrays:
# total 20
# -rw-r--r-- 1 blueelephant48 blueelephant48 9495 Dec  5 12:18 2024-11-15-accessing-and-deleting-elements.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 7883 Dec  5 12:18 2024-11-15-lists_presentation_3.ipynb
#
# ./CSSE/Lessons/Booleans:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 4169 Dec  5 12:18 10-24BOOLEANSHW.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 5768 Dec  5 12:18 2024-10-25-booleanslesson.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 2164 Dec  5 12:18 2024-10-31-booleans-p1.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 7545 Dec  5 12:18 2024-10-31-booleans-p2.ipynb
#
# ./CSSE/Lessons/Classes_and_Methods:
# total 48
# -rw-r--r-- 1 blueelephant48 blueelephant48 10520 Dec  5 12:18 2024-10-27-classes-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  9126 Dec  5 12:18 2024-10-27-classes-methods-in-depth.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7948 Dec  5 12:18 2024-11-04-classes-hw.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 13623 Dec  5 12:18 2024-11-04-classes-static-keyword.ipynb
#
# ./CSSE/Lessons/Conditions:
# total 36
# -rw-r--r-- 1 blueelephant48 blueelephant48  6512 Dec  5 12:18 2024-11-10-conditionals-hacks.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7649 Dec  5 12:18 2024-11-10-conditionals-p1.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 11148 Dec  5 12:18 2024-11-10-conditionals-p2.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7086 Dec  5 12:18 2024-11-10-conditionals-p3.ipynb
#
# ./CSSE/Lessons/Data_Abstractions:
# total 44
# -rw-r--r-- 1 blueelephant48 blueelephant48  6395 Dec  5 12:18 2024-11-06-data_abstraction-homework.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 24766 Dec  5 12:18 2024-11-06-data_abstraction-p1.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  5507 Dec  5 12:18 2024-11-06-data_abstraction-popcornhacks.ipynb
#
# ./CSSE/Lessons/Iteration:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 3021 Dec  5 12:18 2024-11-2-iteration-homework.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 4256 Dec  5 12:18 2024-11-2-iteration-p1.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 5252 Dec  5 12:18 2024-11-5-iteration-p2.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 5671 Dec  5 12:18 2024-11-7-Iteration-P3.ipynb
#
# ./CSSE/Lessons/Mathematic_Expressions:
# total 52
# -rw-r--r-- 1 blueelephant48 blueelephant48 10075 Dec  5 12:18 2024-10-31-impliment_in_rpg.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  3382 Dec  5 12:18 2024-10-31-math-expression-hw.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  8948 Dec  5 12:18 2024-10-31-math-expression-p1-operators.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 10154 Dec  5 12:18 2024-10-31-math-expression-p2-battle.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  3285 Dec  5 12:18 2024-10-31-mathhomework.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7552 Dec  5 12:18 2024-10-31-operators.ipynb
#
# ./CSSE/Lessons/Nested_Conditionals:
# total 24
# -rw-r--r-- 1 blueelephant48 blueelephant48  3364 Dec  5 12:18 2024-10-26-nested_conditionals-hw.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 11192 Dec  5 12:18 2024-10-26-nested_conditionals-p1-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7807 Dec  5 12:18 2024-10-26-nested_conditionals-p2.ipynb
#
# ./CSSE/Lessons/Strings:
# total 20
# -rw-r--r-- 1 blueelephant48 blueelephant48 5692 Dec  5 12:18 2024-10-30-strings-lesson-4-1.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 6804 Dec  5 12:18 2024-10-30-strings-lesson-4-2.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 2204 Dec  5 12:18 2024-10-30-strings-lesson-4-3.ipynb
#
# ./CSSE/Lessons/Variables:
# total 24
# -rw-r--r-- 1 blueelephant48 blueelephant48 16375 Dec  5 12:18 2024-10-25-variables.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  2596 Dec  5 12:18 2024-10-28-variables_hw.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  2531 Dec  5 12:18 2024-10-29-variables_popcorn_hax.ipynb
#
# ./CSSE/javascript:
# total 4
# drwxr-xr-x 3 blueelephant48 blueelephant48 4096 Dec  5 12:18 fundamentals
#
# ./CSSE/javascript/fundamentals:
# total 88
# -rw-r--r-- 1 blueelephant48 blueelephant48 26089 Dec  5 12:18 2024-09-30-data-types-operations.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 39271 Dec  5 12:18 2024-09-30-for_sprites.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 12718 Dec  5 12:18 2024-09-30-variables_IO.ipynb
# drwxr-xr-x 2 blueelephant48 blueelephant48  4096 Dec  5 12:18 images
#
# ./CSSE/javascript/fundamentals/images:
# total 3876
# -rwxr-xr-x 1 blueelephant48 blueelephant48 3851947 Dec  5 12:18 mario.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  113410 Dec  5 12:18 tux.png
#
# ./CSSE/mario:
# total 24
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 _intro
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 background
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 enemy
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 obstacles
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 platform
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 player
#
# ./CSSE/mario/_intro:
# total 4
# -rw-r--r-- 1 blueelephant48 blueelephant48 3582 Dec  5 12:18 2023-07-30-game_mario-intro.ipynb
#
# ./CSSE/mario/background:
# total 32
# -rw-r--r-- 1 blueelephant48 blueelephant48 30574 Dec  5 12:18 2023-08-06-mario_background.ipynb
#
# ./CSSE/mario/enemy:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 26469 Dec  5 12:18 2023-08-05-mario_goomba.ipynb
#
# ./CSSE/mario/obstacles:
# total 52
# -rw-r--r-- 1 blueelephant48 blueelephant48 22616 Dec  5 12:18 2023-08-03-mario_tube.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 25783 Dec  5 12:18 2023-08-04-mario_block.ipynb
#
# ./CSSE/mario/platform:
# total 16
# -rw-r--r-- 1 blueelephant48 blueelephant48 14791 Dec  5 12:18 2023-08-02-mario_platform.ipynb
#
# ./CSSE/mario/player:
# total 12
# -rw-r--r-- 1 blueelephant48 blueelephant48 10618 Dec  5 12:18 2023-08-01-mario_player.ipynb
#
# ./Foundation:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 3974 Dec  5 12:18 2024-08-21-sprint1_plan.ipynb
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 A-pair_programming
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 B-tools_and_equipment
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 C-github_pages
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 D-sass_basics
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 E-frontend_development
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 F-projects
#
# ./Foundation/A-pair_programming:
# total 24
# -rw-r--r-- 1 blueelephant48 blueelephant48  5433 Dec  5 12:18 2023-08-16-pair_programming.md
# -rw-r--r-- 1 blueelephant48 blueelephant48  3918 Dec  5 12:18 2023-08-16-pair_showcase.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 11624 Dec  5 12:18 2023-08-17-pair_habits.ipynb
#
# ./Foundation/B-tools_and_equipment:
# total 296
# -rw-r--r-- 1 blueelephant48 blueelephant48   9767 Dec  5 12:18 2023-08-19-devops_accounts.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48   5931 Dec  5 12:18 2023-08-21-devops_tools-home.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  23630 Dec  5 12:18 2023-08-21-devops_tools-setup.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 209024 Dec 12 12:04 2023-08-22-devops_tools-verify.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  32288 Dec  5 12:18 2023-08-23-devops-githhub_pages-play.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48   9479 Dec  5 12:18 2023-08-23-devops-hacks.ipynb
#
# ./Foundation/C-github_pages:
# total 64
# -rw-r--r-- 1 blueelephant48 blueelephant48 14719 Dec  5 12:18 2023-08-23-github_pages-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 12484 Dec  5 12:18 2023-08-23-github_pages-markdonwn.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 10111 Dec  5 12:18 2023-08-24-github_pages-anatomy.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  3850 Dec  5 12:18 2023-08-25-github_pages-utterances.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 10291 Dec  5 12:18 2023-08-26-github-pages-jekyll.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  2149 Dec  5 12:18 2023-08-27-github-pages-hacks.ipynb
#
# ./Foundation/D-sass_basics:
# total 56
# -rw-r--r-- 1 blueelephant48 blueelephant48 12586 Dec  5 12:18 2023-09-01-SASS-basics-play.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 11648 Dec  5 12:18 2023-09-01-SASS_basics-intro.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 13865 Dec  5 12:18 2023-09-02-SASS_basics-coding.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  8415 Dec  5 12:18 2024-07-20-SASS-hacks.ipynb
#
# ./Foundation/E-frontend_development:
# total 124
# -rw-r--r-- 1 blueelephant48 blueelephant48  6951 Dec  5 12:18 2023-08-27-frontend-basics-playground.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7054 Dec  5 12:18 2023-08-28-frontend-basics-html.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  7204 Dec  5 12:18 2023-08-28-frontend-basics-js-errors.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 16924 Dec  5 12:18 2023-08-29-frontend-basics-of-js.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 20154 Dec  5 12:18 2023-08-30-frontend-basics-js-data-types.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 12454 Dec  5 12:18 2023-08-30-frontend-basics-js-with-html.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 12781 Dec  5 12:18 2023-08-30-frontend-input.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 25250 Dec  5 12:18 2023-08-30-frontend-output_objects.ipynb
#
# ./Foundation/F-projects:
# total 8
# -rw-r--r-- 1 blueelephant48 blueelephant48 7062 Dec  5 12:18 2023-08-30-javascript_project-play.ipynb
#
# ./KASM:
# total 20
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Config_Guides
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Database
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 MultiServer
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 User_Guide
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 Workspaces
#
# ./KASM/Config_Guides:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 4804 Dec  5 12:18 2024-07-05-docker-cronjob-for-containers.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 3646 Dec  5 12:18 2024-07-05-manual-addition-of-docker-images.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 1183 Dec  5 12:18 2024-07-12-security-group-configuration.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 3222 Dec  5 12:18 2024-07-15-manual-registry-addition.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 2088 Dec  5 12:18 2024-07-15-persistent-data.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 2292 Dec  5 12:18 2024-07-31-plans-for-big-meet.ipynb
#
# ./KASM/Database:
# total 44
# -rw-r--r-- 1 blueelephant48 blueelephant48 11567 Dec  5 12:18 2024-08-10-rds-documentation.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  4665 Dec  5 12:18 2024-08-14-migration.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 23557 Dec  5 12:18 2024-08-14-python-api-4-kasm.ipynb
#
# ./KASM/MultiServer:
# total 28
# -rw-r--r-- 1 blueelephant48 blueelephant48 18056 Dec  5 12:18 2024-07-30-autoscale-config.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  3663 Dec  5 12:18 2024-08-07-persistent-storage.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48  3473 Dec  5 12:18 2024-08-14-workspace-registry-admin.ipynb
#
# ./KASM/User_Guide:
# total 16
# -rw-r--r-- 1 blueelephant48 blueelephant48 12450 Dec  5 12:18 2024-11-17-user-kasm.ipynb
#
# ./KASM/Workspaces:
# total 20
# -rw-r--r-- 1 blueelephant48 blueelephant48 8672 Dec  5 12:18 2024-08-14-container-building.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 1285 Dec  5 12:18 2024-08-14-dockerhub-push.ipynb
# -rw-r--r-- 1 blueelephant48 blueelephant48 3038 Dec  5 12:18 2024-08-14-nighthawk-registry.ipynb

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Look for images, print working directory, list files"
# cd $project/images  # this should exist per fastpages
# pwd
# ls -lR
# Out:
# Look for images, print working directory, list files
# /home/blueelephant48/nighthawks/Elise_Portfolio_2025/images
# .:
# total 13896
# -rw-r--r-- 1 blueelephant48 blueelephant48 3827903 Dec  5 12:18 Prof._Stampfers_Stroboscopische_Scheibe_No._X.gif
# drwxr-xr-x 2 blueelephant48 blueelephant48    4096 Dec  5 12:18 about
# -rw-r--r-- 1 blueelephant48 blueelephant48  129584 Dec  5 12:18 agile.webp
# drwxr-xr-x 2 blueelephant48 blueelephant48    4096 Dec  5 12:18 binary
# drwxr-xr-x 2 blueelephant48 blueelephant48    4096 Dec  5 12:18 course-brag
# -rw-r--r-- 1 blueelephant48 blueelephant48  134051 Dec  5 12:18 createusersample.png
# drwxr-xr-x 2 blueelephant48 blueelephant48    4096 Dec  5 12:18 csp-period-5-flowcharts
# -rw-r--r-- 1 blueelephant48 blueelephant48   15406 Dec  5 12:18 favicon.ico
# -rw-r--r-- 1 blueelephant48 blueelephant48  177895 Dec  5 12:18 food.png
# drwxr-xr-x 2 blueelephant48 blueelephant48    4096 Dec  5 12:18 fullstack
# -rw-r--r-- 1 blueelephant48 blueelephant48  244133 Dec  5 12:18 homesample.png
# -rw-r--r-- 1 blueelephant48 blueelephant48
png
# -rw-r--r-- 1 blueelephant48 blueelephant48 322245 Dec  5 12:18 binary_math_conversion.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 298587 Dec  5 12:18 binary_shift.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  19526 Dec  5 12:18 codetable.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  82392 Dec  5 12:18 color_block.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 457749 Dec  5 12:18 color_code.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 301661 Dec  5 12:18 elaboration_of_shift.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  30647 Dec  5 12:18 halt.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 121894 Dec  5 12:18 integer_math_neg.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 125395 Dec  5 12:18 integer_math_pos.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 419775 Dec  5 12:18 logic_gate_application.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 536361 Dec  5 12:18 logic_gate_lab.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 107742 Dec  5 12:18 logic_gates.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 888227 Dec  5 12:18 logic_of_shift.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  17921 Dec  5 12:18 problems.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  38846 Dec  5 12:18 reverse.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 373203 Dec  5 12:18 sample_unicode.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 145986 Dec  5 12:18 truth.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 245559 Dec  5 12:18 twos_complement.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  55105 Dec  5 12:18 unsigned_addition.png
#
# ./course-brag:
# total 3124
# -rw-r--r-- 1 blueelephant48 blueelephant48 536162 Dec  5 12:18 ccr.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 654211 Dec  5 12:18 csa.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 311888 Dec  5 12:18 csa24.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 680581 Dec  5 12:18 csp.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 323986 Dec  5 12:18 csp24.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 270084 Dec  5 12:18 csse.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 362790 Dec  5 12:18 foundation.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  42316 Dec  5 12:18 qr.png
#
# ./csp-period-5-flowcharts:
# total 52
# -rw-r--r-- 1 blueelephant48 blueelephant48  7375 Dec  5 12:18 conditional.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 14195 Dec  5 12:18 if-else-statement.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 26585 Dec  5 12:18 nested-conditionals.png
#
# ./fullstack:
# total 40
# -rw-r--r-- 1 blueelephant48 blueelephant48 15371 Dec  5 12:18 newvars.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  8035 Dec  5 12:18 quickSketch.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 14073 Dec  5 12:18 variables.png
#
# ./jokes:
# total 1788
# -rw-r--r-- 1 blueelephant48 blueelephant48 1040469 Dec  5 12:18 debug.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  245915 Dec  5 12:18 postman.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  533869 Dec  5 12:18 run.png
#
# ./jpa-lesson-images:
# total 740
# -rw-r--r-- 1 blueelephant48 blueelephant48  15657 Dec  5 12:18 columnName.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  48430 Dec  5 12:18 email.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  83139 Dec  5 12:18 haslastname.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  85779 Dec  5 12:18 jpa.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48 201269 Dec  5 12:18 largeterminal.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  62635 Dec  5 12:18 partial.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  75480 Dec  5 12:18 postman.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  42227 Dec  5 12:18 search2.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  27237 Dec  5 12:18 userJpaRepositoryFile.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  37602 Dec  5 12:18 userTable.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48  56784 Dec  5 12:18 walloftext.jpg
#
# ./kasm:
# total 3468
# -rw-r--r-- 1 blueelephant48 blueelephant48 2185677 Dec  5 12:18 kasmUI.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  234406 Dec  5 12:18 kasmlogin.png
# -rw-r--r-- 1 blueelephant48 blueelephant48   37539 Dec  5 12:18 kasmsignup.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  138312 Dec  5 12:18 kasmv2.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  567508 Dec  5 12:18 launch.png
# -rw-r--r-- 1 blueelephant48 blueelephant48   99833 Dec  5 12:18 ncslogin.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  274370 Dec  5 12:18 vskasm.png
#
# ./nitd_rpg:
# total 824
# -rw-r--r-- 1 blueelephant48 blueelephant48   5537 Dec  5 12:18 maze3.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 833503 Dec  5 12:18 mort.png
#
# ./notebooks:
# total 4
# drwxr-xr-x 2 blueelephant48 blueelephant48 4096 Dec  5 12:18 foundation
#
# ./notebooks/foundation:
# total 364
# -rw-r--r-- 1 blueelephant48 blueelephant48 310743 Dec  5 12:18 create_repo.png
# -rw-r--r-- 1 blueelephant48 blueelephant48
png
# -rw-r--r-- 1 blueelephant48 blueelephant48   17116 Dec  5 12:18 lopezanimation.png
# -rw-r--r-- 1 blueelephant48 blueelephant48    6609 Dec  5 12:18 lopezspritesheet3.png
# -rwxr-xr-x 1 blueelephant48 blueelephant48 3851947 Dec  5 12:18 mario.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  111425 Dec  5 12:18 monkey.png
# -rw-r--r-- 1 blueelephant48 blueelephant48   49605 Dec  5 12:18 narwhal_boss.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  181376 Dec  5 12:18 noirio.png
# -rw-r--r-- 1 blueelephant48 blueelephant48   59931 Dec  5 12:18 owl.png
# -rw-r--r-- 1 blueelephant48 blueelephant48   23940 Dec  5 12:18 penguin.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  457104 Dec  5 12:18 skibidiEnemy.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  155875 Dec  5 12:18 skibidiTItan.png
# -rw-r--r-- 1 blueelephant48 blueelephant48   26141 Dec  5 12:18 snowman.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 1683899 Dec  5 12:18 white_mario.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  376506 Dec  5 12:18 white_mario1.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  152460 Dec  5 12:18 zombie.png
#
# ./platformer/transitions:
# total 4756
# -rw-r--r-- 1 blueelephant48 blueelephant48 123315 Dec  5 12:18 IceMinigameEnd.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 750112 Dec  5 12:18 greeceEnd.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  20774 Dec  5 12:18 greenscreen.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 951532 Dec  5 12:18 hillsEnd.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 211655 Dec  5 12:18 hogwartsminiEnd.jpg
# -rw-r--r-- 1 blueelephant48 blueelephant48 859809 Dec  5 12:18 miniEnd.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 917436 Dec  5 12:18 quidditchEnd.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 917788 Dec  5 12:18 waterEnd.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  94865 Dec  5 12:18 winterEnd.png
#
# ./rpg:
# total 640
# -rw-r--r-- 1 blueelephant48 blueelephant48  33742 Dec  5 12:18 fishies.png
# -rw-r--r-- 1 blueelephant48 blueelephant48  13963 Dec  5 12:18 turtle.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 599642 Dec  5 12:18 water.png
#
# ./u8-p1-assets:
# total 208
# -rw-r--r-- 1 blueelephant48 blueelephant48 103745 Dec  5 12:18 qp1.png
# -rw-r--r-- 1 blueelephant48 blueelephant48 102436 Dec  5 12:18 qp2.png

# %% [markdown]
# ### Look inside a Markdown File
# > "cat" reads data from the file and gives its content as output

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# echo "Navigate to project, then navigate to area wwhere files were cloned"
#
# cd $project
# echo "show the contents of README.md"
# echo ""
#
# cat README.md  # show contents of file, in this case markdown
# echo ""
# echo "end of README.md"
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# show the contents of README.md
#
# # Introduction
#
# Nighthawk Pages is a project designed to support students in their Computer Science and Software Engineering education. It offers a wide range of resources including tech talks, code examples, and educational blogs.
#
# GitHub Pages can be customized by the blogger to support computer science learnings as the student works through the pathway of using Javascript, Python/Flask, Java/Spring.
#
# ## Student Requirements
#
# Del Norte HS students will be required to review their personal GitHub Pages at each midterm and final.  This review will contain a compilation of personal work performed within each significant grading period.
#
# In general, Students and Teachers are expected to use GitHub pages to build lessons, complete classroom hacks, perform work on JavaScript games, and serve as a frontend to full-stack applications.
#
# Exchange of information could be:
#
# 1. sharing a file:  `wget "raw-link.ipynb"
# 2. creating a template from this repository
# 3. sharing a fork among team members
# 4. etc.
#
# ---
#
# ## History
#
# This project is in its 3rd revision (aka 3.0).
#
# The project was initially based on Fastpages. But this project has diverged from those roots into an independent entity.  The decision to separate from Fastpages was influenced by the deprecation of Fastpages by authors.  It is believed by our community that the authors of fastpages turned toward Quatro.  After that change of direction fastpages did not align with the Teacher's goals and student needs. The Nighthawk Pages project has more of a raw development blogging need.
#
# ### License
#
# The Apache license has its roots in Fastpages.  Thus, it carries its license forward.  However, most of the code is likely unrecognizable from those roots.
#
# ### Key Features
#
# - **Code Examples**: Provides practical coding examples in JavaScript, including a platformer game, and frontend code for user databases using Python and Java backends.
# - **Educational Blogs**: Offers instructional content on various topics such as developer tools setup, deployment on AWS, SQL databases, machine learning, and data structures. It utilizes Jupyter Notebooks for interactive lessons and coding challenges.
# - **Tools and Integrations**: Features GitHub actions for blog publishing, Utterances for blog commenting, local development support via Makefile and scripts, and styling with the Minima Theme and SASS. It also includes a new integration with GitHub Projects and Issues.
#
# ### Contributions
#
# - **Notable Contributions**: Highlights significant contributions to the project, including theme development, search and tagging functionality, GitHub API integration, and the incorporation of GitHub Projects into GitHub pages. Contributors such as Tirth Thakker, Mirza Beg, and Toby Ledder have played crucial roles in these developments.
#
# - **Blog Contributions**:  Often students contribute articles and blogs to this project.  Their names are typically listed in the front matter of their contributing post.
#
# ---
#
# ## GitHub Pages setup
#
# The absolutes in setup up...
#
# **Activate GitHub Pages Actions**: This step involves enabling GitHub Pages Actions for your project. By doing so, your project will be automatically deployed using GitHub Pages Actions, ensuring that your project is always up to date with the latest changes you push to your repository.
#
# - On the GitHub website for the repository go to the menu: Settings -> Pages ->Build
# - Under the Deployment location on the page, select "GitHub Actions".
#
# **Update `_config.yml`**: You need to modify the `_config.yml` file to reflect your repository's name. This configuration is crucial because it ensures that your project's styling is correctly applied, making your deployed site look as intended rather than unstyled or broken.
#
# ```text
# github_repo: "portfolio_2025"
# baseurl: "/portfolio_2025"
# ```
#
# **Set Repository Name in Makefile**: Adjust the `REPO_NAME` variable in your Makefile to match your GitHub repository's name. This action facilitates the automatic updating of posts and notebooks on your local development server, improving the development process.
#
# ```make
# # Configuration, override port with usage: make PORT=4200
# PORT ?= 4100
# REPO_NAME ?= portfolio_2025
# LOG_FILE = /tmp/jekyll$(PORT).log
# ```
#
# ### Tool requirements
#
# All `GitHub Pages` websites are managed on GitHub infrastructure and use GitHub version control.  Each time we change files in GitHub it initiates a GitHub Action, a continuous integration and development toolset, that rebuilds and publishes the site with Jekyll.
#
# - GitHub uses `Jekyll` to transform your markdown and HTML content into static websites and blogs. [Jekyll](https://jekyllrb.com/).
# - A Linux shell is required to work with this project integration with GitHub Pages, GitHub and VSCode.  Ubuntu is the preferred shell, though MacOS shell is supported as well.  There will be some key setup scripts that follow in the README.
# - Visual Studio Code is the Nighthawk Pages author's preferred code editor and extensible development environment.  VSCode has a rich ecosystem of developer extensions that ease working with GitHub Pages, GitHub, and many programming languages.  Setting up VSCode and extensions will be elaborated upon in this document.
# - An anatomy section in this README will describe GitHub Pages and conventions that are used to organize content and files.  This includes file names, key coding files, metadata tagging of blogs, styling tooling for blogs, etc.
#
# ### Development Environment Setup
#
# Comprehensive start. A topic-by-topic guide to getting this project running is published [here](https://nighthawkcoders.github.io/portfolio_2025/devops/tools/home).
#
# Quick start.  A quick start below is a reminder, but is dependent on your knowledge.  Only follow this instruction if you need a refresher.  Always default to the comprehensive start if any problem occurs.
#
# #### Clone Repo
#
# Run these commands to obtain the project, then locate into the project directory with the terminal, install an extensive set of tools, and make.
#
# ```bash
# git clone <this-repo> # git clone https://github.com/nighthawkcoders/portfolio_2025.git
# cd <repo-dir>/scripts # cd portfolio_2025
# ```
#
# #### Windows WSL and/or Ubuntu Users
#
# - Execute the script: `./activate_ubuntu.sh`
#
# #### macOS Users
#
# - Execute the script: `./activate_macos.sh`
#
# #### Kasm Cloud Desktop Users
#
# - Execute the script: `./activate.sh`
#
# ## Run Server on localhost
#
# To preview the project you will need to "make" the project.
#
# ### Bundle install
#
# The very first time you clone run project you will need to run this Ruby command as the final part of your setup.
#
# ```bash
# bundle install
# ```
#
# ### Start the Server
#
# This requires running terminal commands `make`, `make stop`, `make clean`, or `make convert` to manage the running server.  Logging of details will appear in the terminal.   A `Makefile` has been created in the project to support commands and start processes.
#
# Start the server, this is the best choice for initial and iterative development.  Note. after the initial `make`, you should see files automatically refresh in the terminal on VSCode save.
#
#   ```bash
#   make
#   ```
#
# ### Load web application into the Browser
#
# Start the preview server in the terminal,
# The terminal output from `make` shows the server address. "Cmd" or "Ctl" click the http location to open the preview server in a browser. Here is an example Server address message, click on the Server address to load:...
#
#   ```text
#   http://0.0.0.0:4100/portfolio_2025/
#   ```
#
# ### Regeneration of web application
#
# Save on ".ipynb" or ".md" file activiates "regeneration". An example terminal message is below.  Refresh the browser to see updates after the message displays.
#
#   ```text
#   Regenerating: 1 file(s) changed at 2023-07-31 06:54:32
#       _notebooks/2024-01-04-cockpit-setup.ipynb
#   ```
#
# ### Other "make" commands
#
# Terminal messages are generated from background processes.  At any time, click return or enter in a terminal window to obtain a prompt.  Once you have the prompt you can use the terminal as needed for other tasks.  Always return to the root of project `cd ~/vscode/portfolio_2025` for all "make" actions.
#
# #### Stop the preview server
#
# Stopping the server ends the web server applications running process.  However, it leaves constructed files in the project in a ready state for the next time you run `make`.
#
#   ```bash
#   make stop
#   ```
#
# ### Clean the local web application environment
#
# This command will top the server and "clean" all previously constructed files (ie .ipynb -> .md). This is the best choice when renaming files has created duplicates that are visible when previewing work.
#
#   ```bash
#   make clean
#   ```
#
# ### Observe build errors
#
# Test Jupyter Notebook conversions (ie .ipynb -> .md), this is the best choice to see if an IPYNB conversion error is occurring.
#
#   ```bash
#   make convert
#   ```
#
# ---
#
# ## Development Support
#
# ### File Names in "_posts", "_notebooks"
#
# There are two primary directories for creating blogs.  The "_posts" directory is for authoring in markdown only.  The "_notebooks" allows for markdown, pythons, javascript and more.
#
# To name a file, use the following structure (If dates are in the future, review your config.yml setting if you want them to be viewed).  Review these naming conventions.
#
# - For markdown files in _posts:
#   - year-month-day-fileName.md
#     - GOOD EXAMPLE: 2021-08-02-First-Day.md
#     - BAD EXAMPLE: 2021-8-2-first-day.md
#     - BAD EXAMPLE: first-day.md
#     - BAD EXAMPLE: 2069-12-31-First-Day.md
#
# - For Jupyter notebooks in _notebooks:
#   - year-month-day-fileName.ipynb
#     - GOOD EXAMPLE: 2021-08-02-First-Day.ipynb
#     - BAD EXAMPLE: 2021-8-2-first-day.ipynb
#     - BAD EXAMPLE: first-day.ipynb
#     - BAD EXAMPLE: 2069-12-31-First-Day.ipynb
#
# ### Tags
#
# Tags are used to organize pages by their tag the way to add tags is to add the following to your front matter such as the example seen here `categories: [Tools]` Each item in the same category will be lumped together to be seen easily on the search page.
#
# ### Search
#
# All pages can be searched for using the built-in search bar. This search bar will search for any word in the title of a page or in the page itself. This allows for easily finding pages and information that you are looking for. However, sometimes this may not be desirable so to hide a page from the search you need to add `search_exclude: true` to the front matter of the page. This will hide the page from appearing when the viewer uses search.
#
# ### Navigation Bar
#
# To add pages to the top navigation bar use _config.yml to order and determine which menus you want and how to order them.  Review the_config.yml in this project for an example.
#
# ### Blog Page
#
# There is a blog page that has options for images and a description of the page. This page can help the viewer understand what the page is about and what they can expect to find on the page. The way to add images to a page is to have the following front matter `image: /images/file.jpg` and then the name of the image that you want to use. The image must be in the `images` folder. Furthermore, if you would like the file to not show up on the blog page `hide: true` can be added to the front matter.
#
# ### SASS support
#
# NIGHTHAWK Pages support a variety of different themes that are each overlaid on top of minima. To use each theme, go to the "_sass/minima/custom-styles.scss" file and simply comment or uncomment the theme you want to use.
#
# To learn about the minima themes search for "GitHub Pages minima" and review the README.
#
# To find a new theme search for "Github Pages Themes".
#
# ### Includes
#
# - Nighthawk Pages uses liquid syntax to import many common page elements that are present throughout the repository. These common elements are imported from the _includes directory. If you want to add one of these common elements, use liquid syntax to import the desired element to your file. Here’s an example of the liquid syntax used to import: `{%- include post_list.html -%}` Note that the liquid syntax is surrounded by curly braces and percent signs. This can be used anywhere in the repository.
#
# ### Layouts
#
# - To use or create a custom page layout, make an HTML page inside the _layouts directory, and when you want to use that layout in a file, use the following front matter `layout: [your layout here]`.  All layouts will be written in liquid to define the structure of the page.
#
# ### Metadata
#
# Metadata, also known as "front matter", is a set of key-value pairs that can provide additional information to GitHub Pages about .md and .ipynb files. This can and probably will be used in other file types (ie doc, pdf) if we add them to the system.
#
# In the front matter, you can also define things like a title and description for the page.  Additional front matter is defined to place content on the "Computer Science Lab Notebook" page.  The `courses:` key will place data on a specific page with the nested `week:` placing data on a specific row on the page.  The `type:` key in "front matter" will place the blog under the plans, hacks(ToDo), and tangibles columns.
#
# - In our files, the front matter is defined at the top of the page or the first markdown cell.
#
#   - First, open one of the .md or .ipynb files already included in either your _posts|_notebooks folder.
#
#   - In the .md file, you should notice something similar to this at the top of the page. To see this in your .ipynb files you will need to double-click the markdown cell at the top of the file.
#
#   ```yaml
#   ---
#   toc: true
#   comments: true
#   layout: post
#   title: Jupyter Python Sample
#   description: Example Blog!!!  This shows code and notes from hacks.
#   type: ccc
#   courses: { csa: {week: 5} }
#   ---
#   ```
#
# - The front matter will always have '---' at the top and bottom to distinguish it and each key-value pair will be separated by a ':'.
#
# - Here we can modify things like the title and description.
#
# - The type value will tell us which column this is going to appear under the time box supported pages.  The "ccc" stands for Code, Code, Code.
#
# - The courses will tell us which menu item it will be under, in this case, the `csa` menu, and the `week` tells it what row (week) it will appear under that menu.
#
# end of README.md

# %% [markdown]
# ## Env, Git, and GitHub
#
# > Env(ironment) is used to capture things like the path to the Code or Home directory. Git and GitHub are not only used to exchange code between individuals but are also often used to exchange code through servers, in our case for website deployment. All tools we use have behind-the-scenes relationships with the system they run on (MacOS, Windows, Linux) or a relationship with servers to which they are connected (e.g., GitHub). There is an "env" command in bash. There are environment files and setting files (e.g., `.git/config`) for Git. They both use a key/value concept.
#
# - `env` shows settings for your shell.
# - `git clone` sets up a directory of files.
# - `cd $project` allows the user to move inside that directory of files.
# - `.git` is a hidden directory that is used by Git to establish a relationship between the machine and the Git server on GitHub.

# %%
# %%script bash
#
# # This command has no dependencies
#
# echo "Show the shell environment variables, key on left of equal value on right"
# echo ""
#
# env
# Out:
# Show the shell environment variables, key on left of equal value on right
#
# SHELL=/bin/bash
# PYTHONUNBUFFERED=1
# WSL2_GUI_APPS_ENABLED=1
# WSL_DISTRO_NAME=Ubuntu-24.04
# JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
# PYTHON_FROZEN_MODULES=on
# ELECTRON_RUN_AS_NODE=1
# NAME=Code
# PWD=/home/blueelephant48/nighthawks/Elise_Portfolio_2025/_notebooks/Foundation/B-tools_and_equipment
# LOGNAME=blueelephant48
# VSCODE_ESM_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING=1
# MOTD_SHOWN=update-motd
# HOME=/home/blueelephant48
# LANG=C.UTF-8
# WSL_INTEROP=/run/WSL/511_interop
# LS_COLORS=rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=00:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.avif=01;35:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.webp=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:*~=00;90:*#=00;90:*.bak=00;90:*.crdownload=00;90:*.dpkg-dist=00;90:*.dpkg-new=00;90:*.dpkg-old=00;90:*.dpkg-tmp=00;90:*.old=00;90:*.orig=00;90:*.part=00;90:*.rej=00;90:*.rpmnew=00;90:*.rpmorig=00;90:*.rpmsave=00;90:*.swp=00;90:*.tmp=00;90:*.ucf-dist=00;90:*.ucf-new=00;90:*.ucf-old=00;90:
# WAYLAND_DISPLAY=wayland-0
# FORCE_COLOR=1
# PYDEVD_USE_FRAME_EVAL=NO
# CLICOLOR=1
# CLICOLOR_FORCE=1
# GEM_HOME=/home/blueelephant48/gems
# LESSCLOSE=/usr/bin/lesspipe %s %s
# VSCODE_HANDLES_SIGPIPE=true
# TERM=xterm-color
# LESSOPEN=| /usr/bin/lesspipe %s
# USER=blueelephant48
# GIT_PAGER=cat
# PYTHONIOENCODING=utf-8
# DISPLAY=:0
# SHLVL=2
# PAGER=cat
# VSCODE_CWD=/mnt/c/Users/elise/AppData/Local/Programs/Microsoft VS Code
# MPLBACKEND=module://matplotlib_inline.backend_inline
# XDG_RUNTIME_DIR=/run/user/1000/
# DEBUGINFOD_URLS=https://debuginfod.ubuntu.com
# WSLENV=ELECTRON_RUN_AS_NODE/w:
# VSCODE_WSL_EXT_LOCATION=/mnt/c/Users/elise/.vscode/extensions/ms-vscode-remote.remote-wsl-0.88.5
# XDG_DATA_DIRS=/usr/local/share:/usr/share:/var/lib/snapd/desktop
# PATH=/bin:/home/blueelephant48/.local/bin:/home/blueelephant48/.vscode-server/bin/f1a4fb101478ce6ec82fe9627c43efbf9e98c813/bin/remote-cli:/home/blueelephant48/gems/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Program Files/National Instruments/Shared/OpenVINO/:/mnt/c/Program Files/Eclipse Adoptium/jdk-17.0.12.7-hotspot/bin:/mnt/c/windows/system32:/mnt/c/windows:/mnt/c/windows/System32/Wbem:/mnt/c/windows/System32/WindowsPowerShell/v1.0/:/mnt/c/windows/System32/OpenSSH/:/mnt/c/Program Files/dotnet/:/mnt/c/Program Files/nodejs/:/mnt/c/Program Files/Git/cmd:/mnt/c/Users/elise/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/elise/AppData/Roaming/npm:/mnt/c/Users/elise/AppData/Local/Programs/Microsoft VS Code/bin:/snap/bin:/usr/lib/jvm/java-17-openjdk-amd64/bin:/home/blueelephant48/.vscode-server/bin/f1a4fb101478ce6ec82fe9627c43efbf9e98c813/bin/remote-cli:/home/blueelephant48/gems/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Program Files/National Instruments/Shared/OpenVINO/:/mnt/c/Program Files/Eclipse Adoptium/jdk-17.0.12.7-hotspot/bin:/mnt/c/windows/system32:/mnt/c/windows:/mnt/c/windows/System32/Wbem:/mnt/c/windows/System32/WindowsPowerShell/v1.0/:/mnt/c/windows/System32/OpenSSH/:/mnt/c/Program Files/dotnet/:/mnt/c/Program Files/nodejs/:/mnt/c/Program Files/Git/cmd:/mnt/c/Users/elise/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/elise/AppData/Roaming/npm:/mnt/c/Users/elise/AppData/Local/Programs/Microsoft VS Code/bin:/snap/bin:/usr/lib/jvm/java-17-openjdk-amd64/bin
# DBUS_SESSION_BUS_ADDRESS=unix:path=/run/user/1000/bus
# VSCODE_NLS_CONFIG={"userLocale":"en","osLocale":"en","resolvedLanguage":"en","defaultMessagesFile":"/home/blueelephant48/.vscode-server/bin/f1a4fb101478ce6ec82fe9627c43efbf9e98c813/out/nls.messages.json","locale":"en","availableLanguages":{}}
# HOSTTYPE=x86_64
# PULSE_SERVER=unix:/mnt/wslg/PulseServer
# VSCODE_HANDLES_UNCAUGHT_ERRORS=true
# VSCODE_IPC_HOOK_CLI=/run/user/1000/vscode-ipc-232feafc-20e4-4e5c-b5d1-b40d387a40fa.sock
# _=/bin/env

# %%
# %%script bash
#
# # Extract saved variables
# source /tmp/variables.sh
#
# cd $project
#
# echo ""
# echo "show the secrets of .git config file"
# cd .git
# ls -l config
#
# echo ""
# echo "look at config file"
# cat config
# Out:
# show the secrets of .git config file
# -rw-r--r-- 1 blueelephant48 blueelephant48 312 Dec  6 11:41 config
#
# look at config file
# [core]
# 	repositoryformatversion = 0
# 	filemode = true
# 	bare = false
# 	logallrefupdates = true
# [remote "origin"]
# 	url = https://github.com/blueelephant48/Elise_Portfolio_2025.git
# 	fetch = +refs/heads/*:refs/remotes/origin/*
# [branch "main"]
# 	remote = origin
# 	merge = refs/heads/main
# 	vscode-merge-base = origin/main

# %% [markdown]
# ## Advanced Shell project
#
# > This example was requested by a student (Jun Lim, CSA). The request was to make a Jupyter file using bash; I adapted the request to markdown. This type of thought will have great extrapolation to coding and possibilities of using Lists, Arrays, or APIs to build user interfaces. JavaScript is a language where building HTML is very common.
#
# > To get more interesting output from the terminal, this will require using something like mdless (https://github.com/ttscoff/mdless). This enables seeing markdown in rendered format.
# - On Desktop [Install PKG from MacPorts](https://www.macports.org/install.php)
# - In Terminal on MacOS
#     - [Install ncurses](https://ports.macports.org/port/ncurses/)
#     - ```gem install mdless```
#
# > Output of the example is much nicer in "Jupyter"
#
# This is starting the process of documentation.

# %%
# %%script bash
#
# # This example has an error in VSCode; it runs best on Jupyter
# cd /tmp
#
# file="sample.md"
# if [ -f "$file" ]; then
#     rm $file
# fi
#
# # Create a markdown file using tee and here document (<<EOF)
# tee -a $file >/dev/null <<EOF
# # Show Generated Markdown
# This introductory paragraph and this line and the title above are generated using tee with the standard input (<<) redirection operator.
# - This bulleted element is still part of the tee body.
# EOF
#
# # Append additional lines to the markdown file using echo and redirection (>>)
# echo "- This bulleted element and lines below are generated using echo with standard output (>>) redirection operator." >> $file
# echo "- The list definition, as is, is using space to separate lines. Thus the use of commas and hyphens in output." >> $file
#
# # Define an array of actions and their descriptions
# actions=("ls,list-directory" "cd,change-directory" "pwd,present-working-directory" "if-then-fi,test-condition" "env,bash-environment-variables" "cat,view-file-contents" "tee,write-to-output" "echo,display-content-of-string" "echo_text_>\$file,write-content-to-file" "echo_text_>>\$file,append-content-to-file")
#
# # Loop through the actions array and append each action to the markdown file
# for action in ${actions[@]}; do
#   action=${action//-/ }  # Convert dash to space
#   action=${action//,/: } # Convert comma to colon
#   action=${action//_text_/ \"sample text\" } # Convert _text_ to "sample text", note escape character \ to avoid "" having meaning
#   echo "    - ${action//-/ }" >> $file  # Append action to file
# done
#
# echo ""
# echo "File listing and status"
# ls -l $file # List file details
# wc $file   # Show word count
# mdless $file  # Render markdown from terminal (requires mdless installation)
#
# rm $file  # Clean up temporary file
# Out:
# File listing and status
# -rw-r--r-- 1 blueelephant48 blueelephant48 808 Dec 12 12:04 sample.md
#  15 132 808 sample.md
# bash: line 36: mdless: command not found

# %% [markdown]
# ## Display Shell commands help using `man`
#
# > The previous example used a markdown file to store a list of actions and their descriptions. This example uses the `man` command to generate a markdown file with descriptions of the commands. The markdown file is then displayed using `mdless`.
#
# In coding, we should try to get data from the content creators instead of creating it on our own. This approach has several benefits:
# - **Accuracy**: Descriptions from `man` pages are authoritative and accurate, as they come directly from the documentation provided by the command's developers.
# - **Consistency**: Automatically generating descriptions ensures consistency in formatting and terminology.
# - **Efficiency**: It saves time and effort, especially when dealing with a large number of commands.
# - **Up-to-date Information**: `man` pages are regularly updated with the latest information, ensuring that the descriptions are current.

# %%
# %%script bash
#
# # This example has an error in VSCode; it runs best on Jupyter
# cd /tmp
#
# file="sample.md"
# if [ -f "$file" ]; then
#     rm $file
# fi
#
# # Set locale to C to avoid locale-related errors
# export LC_ALL=C
#
# # Create a markdown file using tee and here document (<<EOF)
# tee -a $file >/dev/null <<EOF
# # Show Generated Markdown
# This introductory paragraph and this line and the title above are generated using tee with the standard input (<<) redirection operator.
# - This bulleted element is still part of the tee body.
# EOF
#
# # Append additional lines to the markdown file using echo and redirection (>>)
# echo "- This bulleted element and lines below are generated using echo with standard output (>>) redirection operator." >> $file
# echo "- The list definition, as is, is using space to separate lines. Thus the use of commas and hyphens in output." >> $file
#
# # Define an array of commands
# commands=("ls" "cat" "tail" "pwd" "env" "grep" "awk" "sed" "curl" "wget")
#
# # Loop through the commands array and append each command description to the markdown file
# for cmd in ${commands[@]}; do
#   description=$(man $cmd | col -b | awk '/^NAME/{getline; print}')
#   echo "    - $description" >> $file
# done
#
# echo ""
# echo "File listing and status"
# ls -l $file # List file details
# wc $file   # Show word count
# mdless $file  # Render markdown from terminal (requires mdless installation)
#
# rm $file  # Clean up temporary file
# Out:
# troff:<standard input>:1039: warning [p 9, 0.2i]: cannot adjust line
# troff:<standard input>:1296: warning [p 11, 5.2i]: cannot adjust line
# troff:<standard input>:254: warning [p 3, 3.7i]: cannot adjust line
# troff:<standard input>:583: warning [p 6, 0.2i]: cannot adjust line
# troff:<standard input>:645: warning [p 6, 6.5i]: cannot adjust line
# troff:<standard input>:664: warning [p 6, 8.7i]: cannot adjust line
# troff:<standard input>:728: warning [p 7, 4.5i]: cannot adjust line
# troff:<standard input>:746: warning [p 7, 6.3i]: cannot adjust line
# troff:<standard input>:784: warning [p 8, 0.0i]: cannot adjust line
# troff:<standard input>:1138: warning [p 11, 3.5i]: cannot adjust line
# troff:<standard input>:1414: warning [p 13, 6.2i]: cannot adjust line
# troff:<standard input>:1415: warning [p 13, 6.5i]: cannot adjust line
# troff:<standard input>:1471: warning [p 13, 12.3i]: cannot adjust line
# troff:<standard input>:1652: warning [p 15, 0.0i]: cannot adjust line
# troff:<standard input>:1652: warning [p 15, 0.2i]: cannot adjust line
# troff:<standard input>:1652: warning [p 15, 0.3i]: cannot adjust line
# troff:<standard input>:1746: warning [p 15, 10.3i]: cannot adjust line
# troff:<standard input>:1794: warning [p 16, 0.7i]: cannot adjust line
# troff:<standard input>:1794: warning [p 16, 0.8i]: cannot adjust line
# troff:<standard input>:1794: warning [p 16, 1.0i]: cannot adjust line
# troff:<standard input>:1936: warning [p 16, 13.5i]: cannot adjust line
# troff:<standard input>:1956: warning [p 17, 1.7i]: cannot adjust line
# troff:<standard input>:1956: warning [p 17, 1.8i]: cannot adjust line
# troff:<standard input>:2409: warning [p 20, 7.5i]: cannot adjust line
# troff:<standard input>:526: warning [p 9, 5.2i]: cannot break line
# troff:<standard input>:2226: warning [p 36, 9.0i]: cannot adjust line
# troff:<standard input>:2261: warning [p 37, 3.2i]: cannot adjust line
# troff:<standard input>:2559: warning [p 42, 0.3i]: cannot break line
# File listing and status
# -rw-r--r-- 1 blueelephant48 blueelephant48 1016 Dec 12 12:04 sample.md
#   15  159 1016 sample.md
# bash: line 37: mdless: command not found
